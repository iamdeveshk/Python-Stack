# %% [markdown]
# ### Namespaces
#
# A namespace is a space that holds names(identifiers).Programmatically speaking, namespaces are dictionary of identifiers(keys) and their objects(values)
#
# There are 4 types of namespaces:
# - Builtin Namespace
# - Global Namespace
# - Enclosing Namespace
# - Local Namespace

# %%
# a= 2 ,b =3 namespaces = {a:2,b:3}

# %% [markdown]
# python tutor -> visualise

# %% [markdown]
# ### Scope and LEGB Rule
#
# A scope is a textual region of a Python program where a namespace is directly accessible.
#
# The interpreter searches for a name from the inside out, looking in the local, enclosing, global, and finally the built-in scope. If the interpreter doesn’t find the name in any of these locations, then Python raises a NameError exception.

# %%
# local and global
# global var
a = 2

def temp():
  # local var
  b = 3
  print(b)

temp()
print(a)
# Out:
# 3
# 2

# %%
# local and global -> same name -> they're part of two diffferent namespaces and scopes
a = 2

def temp():
  # local var
  a = 3
  print(a)

temp()
print(a)
# Out:
# 3
# 2

# %%
# local and global -> local does not have but global has
#LEGB Rule
a = 2

def temp():
  # local var
  print(a)

temp()
print(a)
# Out:
# 2
# 2

# %%
# local and global -> editing global
#can read, see but can't change global variable inside local space
a = 2

def temp():
  # local var
  a += 1
  print(a)

temp()
print(a)
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# /tmp/ipykernel_1125/1555806570.py in <cell line: 0>()
#       8   print(a)
#       9
# ---> 10 temp()
#      11 print(a)
#
# /tmp/ipykernel_1125/1555806570.py in temp()
#       5 def temp():
#       6   # local var
# ----> 7   a += 1
#       8   print(a)
#       9
#
# UnboundLocalError: cannot access local variable 'a' where it is not associated with a value

# %%
#jugaad
a = 2

def temp():
  # local var
  global a
  a += 1
  print(a)

temp()
print(a) #global me bhi changes ho gye
# Out:
# 3
# 3

# %%
# local and global -> global created inside local
# not a good programming practice
#global nhi tha but ban gya
def temp():
  # local var
  global a #global me a ban gya
  a = 1
  print(a)

temp()
print(a)
# Out:
# 1
# 1

# %%
# local and global -> function parameter is local
#function ka parameter always local
def temp(z):
  # local var
  print(z)

a = 5
temp(5)
print(a)
print(z) #can't access z globally
# Out:
# 5
# 5
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1125/3960771262.py in <cell line: 0>()
#       8 temp(5)
#       9 print(a)
# ---> 10 print(z) #can't access z globally
#
# NameError: name 'z' is not defined

# %%
# built-in scope
import builtins
print(dir(builtins)) #dir is of print function
print(dir(builtins)) #dir is of print function
# Out:
# ['ArithmeticError', 'AssertionError', 'AttributeError', 'BaseException', 'BaseExceptionGroup', 'BlockingIOError', 'BrokenPipeError', 'BufferError', 'BytesWarning', 'ChildProcessError', 'ConnectionAbortedError', 'ConnectionError', 'ConnectionRefusedError', 'ConnectionResetError', 'DeprecationWarning', 'EOFError', 'Ellipsis', 'EncodingWarning', 'EnvironmentError', 'Exception', 'ExceptionGroup', 'False', 'FileExistsError', 'FileNotFoundError', 'FloatingPointError', 'FutureWarning', 'GeneratorExit', 'IOError', 'ImportError', 'ImportWarning', 'IndentationError', 'IndexError', 'InterruptedError', 'IsADirectoryError', 'KeyError', 'KeyboardInterrupt', 'LookupError', 'MemoryError', 'ModuleNotFoundError', 'NameError', 'None', 'NotADirectoryError', 'NotImplemented', 'NotImplementedError', 'OSError', 'OverflowError', 'PendingDeprecationWarning', 'PermissionError', 'ProcessLookupError', 'RecursionError', 'ReferenceError', 'ResourceWarning', 'RuntimeError', 'RuntimeWarning', 'StopAsyncIteration', 
# ...

# %%
# how to see all the built-ins

# %%
# renaming built-ins
L = [1,2,3] #global scope
print(max(L)) #builtin scope

#LEGB rule
def max():
  print('hello')

print(max())
print(max(L))


#here global max is executed not the builtin because it was found first
#builtin scope is oveerride
# Out:
# 3
# hello
# None
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_4829/2791562457.py in <cell line: 0>()
#       8
#       9 print(max())
# ---> 10 print(max(L))
#      11
#      12
#
# TypeError: max() takes 0 positional arguments but 1 was given

# %%
# Enclosing scope
def outer():
  def inner(): #local
    print('inner fucntion')
  inner()
  print('outer function')


outer() #global
print('main program')
# Out:
# inner fucntion
# outer function
# main program

# %%
# Enclosing scope
#local -L
def outer():
  a = 3 #enclosing -> non local
  def inner(): #local
    a = 4
    print(a)
  inner()
  print('outer function')

a = 1 #global
outer() #global
print('main program')
# Out:
# 4
# outer function
# main program

# %%
# Enclosing scope

#LEGB Rule

#Enclosing -E
def outer():
  a = 3 #enclosing -> non local
  def inner():
    print(a)
  inner()
  print('outer function')

a = 1
outer()
print('main program')
# Out:
# 3
# outer function
# main program

# %%
#Global
def outer():
  def inner():
    print(a)
  inner()
  print('outer function')

a = 1
outer()
print('main program')
# Out:
# 1
# outer function
# main program

# %%
#builtin -> LEG me nhi mila to builtin me find kroge
def outer():
  def inner():
    print(a)
  inner()
  print('outer function')


outer()
print('main program')
# Out:
# 1
# outer function
# main program

# %%
# nonlocal keyword

#can't change

def outer():
  a = 1
  def inner():
    a += 1
    print('inner',a)
  inner()
  print('outer',a)


outer()
print('main program')
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# /tmp/ipykernel_4829/397148100.py in <cell line: 0>()
#      12
#      13
# ---> 14 outer()
#      15 print('main program')
#
# /tmp/ipykernel_4829/397148100.py in outer()
#       8     a += 1
#       9     print('inner',a)
# ---> 10   inner()
#      11   print('outer',a)
#      12
#
# /tmp/ipykernel_4829/397148100.py in inner()
#       6   a = 1
#       7   def inner():
# ----> 8     a += 1
#       9     print('inner',a)
#      10   inner()
#
# UnboundLocalError: cannot access local variable 'a' where it is not associated with a value

# %%
def outer():
  a = 1
  def inner():
    nonlocal a
    a += 1
    print('inner',a)
  inner()
  print('outer',a)


outer()
print('main program')
# Out:
# inner 2
# outer 2
# main program

# %%
# Summary

# %% [markdown]
# ### Decorators
#
# A decorator in python is a function that receives another function as input and adds some functionality(decoration) to and it and returns it.
#
# This can happen only because python functions are 1st class citizens.
#
# There are 2 types of decorators available in python
# - `Built in decorators` like `@staticmethod`, `@classmethod`, `@abstractmethod` and `@property` etc
# - `User defined decorators` that we programmers can create according to our needs

# %%
# Python are 1st class function

def modify(func,num):
  return func(num)

def square(num):
  return num**2

modify(square,2)
# Out:
# 4

# %%
# simple example

def my_decorator(func):
  def wrapper(): #generally weapper is the name
    print('***********************')
    func() #fubctio is beung called here
    print('***********************')
  return wrapper #returns the function itself -> definition of decorator

def hello():
  print('i am devesh')

a = my_decorator(hello)
a()
# Out:
# ***********************
# i am devesh
# ***********************

# %%
 # more functions

# %%
#ek code hai abhi important

# %%
# how this works -> closure?

# %%
# python tutor

# %%
# Better syntax?
# simple example

def my_decorator(func):
  def wrapper():
    print('***********************')
    func()
    print('***********************')
  return wrapper

@my_decorator #->> shortcut
def hello():
  print('hello')

hello()
# Out:
# ***********************
# hello
# ***********************

# %%
# anything meaningful?
import time

def timer(func):
  def wrapper():
    start = time.time()
    func()
    print('time taken by:',func.__name__,time.time()-start)
  return wrapper

@timer
def hello():
  print('hello')
  time.sleep(2)

@timer
def display():
  print('displayign something')
  time.sleep(4)

@timer
def square(num):
  time.sleep(1)
  return num**2

hello()
square(2)
# Out:
# hello
# time taken by: hello 2.0002129077911377
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1063/3247973392.py in <cell line: 0>()
#      25
#      26 hello()
# ---> 27 square(2)
#
# TypeError: timer.<locals>.wrapper() takes 0 positional arguments but 1 was given

# %%
# A big problem -> decorator will always work with only fucntion that doesn't require any input

# %%
# anything meaningful?
import time

def timer(func):
  def wrapper(*args):
    start = time.time()
    func(*args)
    print('time taken by:',func.__name__,time.time()-start)
  return wrapper

@timer
def hello():
  print('hello')
  time.sleep(2)

@timer
def display():
  print('displaying something')
  time.sleep(4)

@timer
def square(num):
  time.sleep(1)
  print(num**2)

hello() #this function will not be used without decorator now
square(2)
# Out:
# hello
# time taken by: hello 2.000203847885132
# 4
# time taken by: square 1.0002775192260742

# %%
# One last example -> decorators with arguments

# %%
def square(num):
  print(num**2)
square(4)
# Out:
# 16

# %%
square('hehe')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1063/2686426143.py in <cell line: 0>()
# ----> 1 square('hehe')
#
# /tmp/ipykernel_1063/4246737922.py in square(num)
#       1 def square(num):
# ----> 2   print(num**2)
#       3 square(4)
#
# TypeError: unsupported operand type(s) for ** or pow(): 'str' and 'int'

# %%
def sanity_check(data_type):
  def outer_wrapper(func):
    def inner_wrapper(*args):
      if type(*args) == data_type:
        func(*args)
      else:
        raise TypeError('Ye datatype nhi chalega')
    return inner_wrapper
  return outer_wrapper

@sanity_check(int)
def square(num):
  print(num**2)
square(2)

@sanity_check(str)
def greet(name):
  print('hello',name)
greet('nitish')
# Out:
# 4
# hello nitish
